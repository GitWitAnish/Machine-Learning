# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data = ['Low', 'Medium', 'High']

encoded = le.fit_transform(data)
print(encoded)
# Out:
# [1 2 0]

# %%
import pandas as pd

df = pd.DataFrame({
    'City': ['Kathmandu', 'Pokhara', 'Kathmandu']
})

df_encoded = pd.get_dummies(df, columns=['City'])
print(df_encoded)
# Out:
#    City_Kathmandu  City_Pokhara
# 0            True         False
# 1           False          True
# 2            True         False
