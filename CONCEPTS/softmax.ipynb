# %%
import tensorflow as tf
import numpy as np
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
# Features (2D points)
X = np.array([
    [1, 2],
    [2, 1],
    [3, 3],
    [6, 5],
    [7, 7],
    [8, 6]
], dtype=float)

# Labels (3 classes)
y = np.array([0, 0, 1, 1, 2, 2])

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(2,)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  # 3 classes
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(X, y, epochs=200, verbose=0)

# %%
probs = model.predict(X)

print("Softmax probabilities:\n", probs)
print("Sum of probabilities:", probs[0].sum())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Softmax probabilities:
#  [[0.31475988 0.3277709  0.35746923]
#  [0.28656393 0.33758032 0.3758557 ]
#  [0.20891026 0.35102913 0.44006062]
#  [0.09802627 0.3509068  0.5510669 ]
#  [0.06607445 0.33737317 0.5965523 ]
#  [0.05812907 0.33576465 0.6061062 ]]
# Sum of probabilities: 1.0

# %%
pred_classes = np.argmax(probs, axis=1)
print("Predicted classes:", pred_classes)
# Out:
# Predicted classes: [2 2 2 2 2 2]
